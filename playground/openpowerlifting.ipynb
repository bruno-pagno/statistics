# %%
# Chapter 1: Exploratory Data Analysis
import pandas as pd

data = pd.read_csv('../datasets/openpowerlifting.csv')
data
# Out:
#         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 386409    8481   William Barabas   M   Multi-ply   NaN        Elite
# 386410    8481      Justin Zottl   M   Multi-ply   NaN        Elite
# 386411    8481     Jake Anderson   M   Multi-ply   NaN        Elite
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN        Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN        Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# ...

# %%
bodyweight = data['BodyweightKg']
print('bodyweight mean', bodyweight.mean())
print('bodyweight min', bodyweight.min())
print('bodyweight max', bodyweight.max())
# Out:
# bodyweight mean 86.93491168244744
# bodyweight min 15.88
# bodyweight max 242.4

# %%
categories = data['Division'].unique()
print('number of categories:', len(categories))
print(categories)
# Out:
# number of categories: 4247
# ['Mst 45-49' 'Mst 40-44' 'Open Senior' ... 'Pro HW' 'Pro Heavy'
#  'Pro Light']

# %%
bench_mean = data['BodyweightKg'].dropna().mean()
squat_mean = data['BestSquatKg'].dropna().mean()
deadlift_mean = data['BestDeadliftKg'].dropna().mean()
print('bench mean:', bench_mean)
print('squat mean:', squat_mean)
print('deadlift mean:', deadlift_mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bk/rv5n6dl138s0tkw_v03v3sh00000gn/T/ipykernel_13108/3657442212.py in <module>
# ----> 1 bench_mean = data['BodyweightKg'].dropna().mean(trim=0.1)
#       2 squat_mean = data['BestSquatKg'].dropna().mean()
#       3 deadlift_mean = data['BestDeadliftKg'].dropna().mean()
#       4 print('bench mean:', bench_mean)
#       5 print('squat mean:', squat_mean)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ...

# %%
bench_max = data['BodyweightKg'].dropna().max()
squat_max = data['BestSquatKg'].dropna().max()
deadlift_max = data['BestDeadliftKg'].dropna().max()
print('bench max:', bench_max)
print('squat max:', squat_max)
print('deadlift max:', deadlift_max)
bench_min = data['BodyweightKg'].dropna().min()
squat_min = data['BestSquatKg'].dropna().min()
deadlift_min = data['BestDeadliftKg'].dropna().min()
print('bench max:', bench_min)
print('squat max:', squat_min, '<- attemp fail or broken data?')
print('deadlift max:', deadlift_min, '<- attemp fail or broken data?')
# Out:
# bench max: 242.4
# squat max: 573.79
# deadlift max: 460.4
# bench max: 15.88
# squat max: -477.5 <- attemp fail or broken data?
# deadlift max: -410.0 <- attemp fail or broken data?
